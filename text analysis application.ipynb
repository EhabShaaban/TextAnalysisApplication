# %%
fileName = input("Enter file Name: ")
with open(fileName) as f:
    text = f.read()
print(text)

def count_char(text, char):
    count=0
    for c in text:
        if c == char:
            count+=1
    return count

for char in "ABCDEFGHIJKLMNOPQRSTUVWXYZ" and "abcdefghijklmnopqrstuvwxyz":
    percentage = 100 * count_char(text, char) / len(text)
    print("\n letter: {0} is taking {1}% of the text and that is {2}".format(char, round(percentage,2), count_char(text, char)))
# Out:
# Enter file Name: hacker_rank_valeo_english_exam.txt
# Dear Hinata,
#
# I hope this mail finds you well, and you're doing great.
#
# I think you will be so happy to hear this, but i booked my flight to Tokyo finally, i'm so excited about this.
#
# i was wondering if you can meet me when my flight arrives, and show me that cat club you was talking about,
#
# i saw some pictures online of it and it was so awesome and kept laughing all night long, i'm so excited to visit it.
#
# see you there buddy, and can't wait to see Tokyo.
#
# yours sincerely,
#
# Ehab Shaaban
#
#  letter: a is taking 6.71% of the text and that is 33
#
#  letter: b is taking 1.83% of the text and that is 9
#
#  letter: c is taking 1.63% of the text and that is 8
#
#  letter: d is taking 2.64% of the text and that is 13
#
#  letter: e is taking 6.71% of the text and that is 33
#
#  letter: f is taking 1.22% of the text and that is 6
#
#  letter: g is taking 2.03% of the text and that is 10
#
#  letter: h is taking 3.46% of the text and that is 17
#
#  letter: i is taking 6.91% of the text and that is 34
#
#  letter: j is taking 0.0% of the text and that is 0
#
#  letter: k is taking 1.22% of the text and that is 6
#
#  letter: l is taking 3.46% of the text and that is 17
#
#  letter: m is taking 2.03% of the text and that is 10
#
#  letter: n is taking 4.67% of the text and that is 23
#
#  letter: o is taking 6.5% of the text and that is 32
#
#  letter: p is taking 1.02% of the text and that is 5
#
#  letter: q is taking 0.0% of the text and that is 0
#
#  letter: r is taking 2.24% of the text and that is 11
#
#  letter: s is taking 4.47% of the text and that is 22
#
#  letter: t is taking 6.5% of the text and that is 32
#
#  letter: u is taking 2.85% of the text and that is 14
#
#  letter: v is taking 0.41% of the text and that is 2
#
#  letter: w is taking 2.24% of the text and that is 11
#
#  letter: x is taking 0.41% of the text and that is 2
#
#  letter: y is taking 3.05% of the text and that is 15
#
#  letter: z is taking 0.0% of the text and that is 0
